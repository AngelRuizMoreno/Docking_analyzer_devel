# %% [markdown]
# # Libraries

# %%
import re
import os
import glob
from pprint import pprint
import pandas as pd
import matplotlib as mt
from matplotlib import pyplot as plt
from matplotlib import pylab
import openbabel as obabel
import pybel as babel

# %%
# %matplotlib inline
# %matplotlib notebook
# Matplotlib options
# %matplotlib inline
mt.style.use('ggplot')
pylab.rcParams['figure.figsize'] = 12, 8

# %% [markdown]
# # Working with AutodockVina output (pdbqt) files

# %%
os.chdir ('/Users/angel/Dropbox/Doctorado/Experimentos/pharmacophorefragments_CD44_VINA/Docking/out_files/')
files=[]
names =[]
scores=[]
mass=[]
formula=[]
smiles=[]
model=[]
het_atoms=[] 
rescoring=[]
for file in glob.glob("*.pdbqt"):
    with open(file,'rt') as pdbqt_file:
        for line in pdbqt_file:
            line = line.strip()
            if "VINA RESULT" in line:
                neg = re.search(r'-\d.\d', line)
                neg_2= re.search (r'-\d\d.\d',line)
                if neg:
                    files.append (pdbqt_file.name)
                    scores.append (float(neg.group()))
                
                elif neg_2:
                    files.append (pdbqt_file.name)
                    scores.append (float(neg_2.group()))
                
                if not (neg or neg_2):
                    files.append (pdbqt_file.name) 
                    scores.append ('positive value, sorry I can´t keep it (yet)')
                   
    for mol in babel.readfile("pdbqt",file):
        ha=[]
        names.append (mol.title)
        mass.append (mol.molwt)
        formula.append (mol.formula)
        model.append (mol.data['MODEL'])
        smiles.append (mol)
        for atom in mol.atoms:
            if atom.atomicnum!=6:
                if atom.atomicnum !=1:
                    ha.append (atom.atomicnum)
        het_atoms.append (len(ha))
        rescoring.append ((float(neg.group())/len(ha)))
                    
d={ 'file':pd.Series(files),
    'score':pd.Series(scores),
    'model':pd.Series (model),
    'compound name':pd.Series(names),
    'molecular formula': pd.Series (formula),
    'molecular weight': pd.Series (mass),
    'smiles': pd.Series (smiles),
    'het_atoms':pd.Series (het_atoms),
    'rescoring':pd.Series (rescoring)}
table=pd.DataFrame (d)

# %%
table
# Out:
#                          file  score model compound name molecular formula  \
# 0      outl1589_3D_H_Ch.pdbqt   -4.0     1         *****          C9H16NO2
# 1      outl1589_3D_H_Ch.pdbqt   -3.9     2         *****          C9H16NO2
# 2      outl1589_3D_H_Ch.pdbqt   -3.8     3         *****          C9H16NO2
# 3      outl1589_3D_H_Ch.pdbqt   -3.8     4         *****          C9H16NO2
# 4      outl1589_3D_H_Ch.pdbqt   -3.7     5         *****          C9H16NO2
# 5      outl1589_3D_H_Ch.pdbqt   -3.7     6         *****          C9H16NO2
# 6      outl1589_3D_H_Ch.pdbqt   -3.7     7         *****          C9H16NO2
# 7      outl1589_3D_H_Ch.pdbqt   -3.7     8         *****          C9H16NO2
# 8      outl1589_3D_H_Ch.pdbqt   -3.4     9         *****          C9H16NO2
# 9      outl1638_3D_H_Ch.pdbqt   -4.2     1         *****          C11H17N2
# 10     outl1638_3D_H_Ch.pdbqt   -3.9     2         *****          C11H17N2
# 11     outl1638_3D_H_Ch.pdbqt   -3.8     3         *****          C11H17N2
# 12     outl1638_3D_H_Ch.pdbqt   -3.8     4         *****          C11H17N2
# 13     outl1638_3D_H_Ch.pdbqt   -3.8     5         *****          C11H17N2
# 14     outl1638_3D_H_Ch.pdbqt   -3.8     6         *****          C11H17N2
# 15     outl1638_3D_H_Ch.pdbqt   -3.7     7         *****          C11H17N2
# 16     outl1638_3D_H_Ch.pdbqt   -3.7     8         *****          C11H17N2
# 17     outl1638_3D_H_Ch.pdbqt   -3.7     9         *****          C11H17N2
# 18     outl1768_3D_H_Ch.pdbqt   -4.8     1         *****         C10H11NO2
# 19     outl1768_3D_H_Ch.pdbqt   -4.5     2         *****         C10H11NO2
# 20     outl1768_3D_H_Ch.pdbqt   -4.4     3         *****         C10H11NO2
# 21     outl1768_3D_H_Ch.pdbqt   -4.2     4         *****         C10H11NO2
# 22     outl1768_3D_H_Ch.pdbqt   -4.2     5         *****         C10H11NO2
# 23     outl1768_3D_H_Ch.pdbqt   -4.1     6         *****         C10H11NO2
# 24     outl1768_3D_H_Ch.pdbqt   -4.0     7         *****         C10H11NO2
# 25     outl1768_3D_H_Ch.pdbqt   -4.0     8         *****         C10H11NO2
# 26     outl1768_3D_H_Ch.pdbqt   -3.9     9         *****         C10H11NO2
# 27     outl3109_3D_H_Ch.pdbqt   -3.9     1         *****          C9H15F3N
# 28     outl3109_3D_H_Ch.pdbqt   -3.8     2         *****          C9H15F3N
# 29     outl3109_3D_H_Ch.pdbqt   -3.8     3         *****          C9H15F3N
# ...                       ...    ...   ...           ...               ...
# 22578  outl2244_3D_H_Ch.pdbqt   -4.1     7         *****        C10H12F3N2
# 22579  outl2244_3D_H_Ch.pdbqt   -4.0     8         *****        C10H12F3N2
# 22580  outl2244_3D_H_Ch.pdbqt   -4.0     9         *****        C10H12F3N2
# 22581  outl2314_3D_H_Ch.pdbqt   -4.3     1         *****          C10H12NO
# 22582  outl2314_3D_H_Ch.pdbqt   -4.1     2         *****          C10H12NO
# 22583  outl2314_3D_H_Ch.pdbqt   -4.0     3         *****          C10H12NO
# 22584  outl2314_3D_H_Ch.pdbqt   -3.9     4         *****          C10H12NO
# 22585  outl2314_3D_H_Ch.pdbqt   -3.7     5         *****          C10H12NO
# 22586  outl2314_3D_H_Ch.pdbqt   -3.7     6         *****          C10H12NO
# 22587  outl2314_3D_H_Ch.pdbqt   -3.6     7         *****          C10H12NO
# 22588  outl2314_3D_H_Ch.pdbqt   -3.5     8         *****          C10H12NO
# 22589  outl2314_3D_H_Ch.pdbqt   -3.5     9         *****          C10H12NO
# 22590  outl2731_3D_H_Ch.pdbqt   -4.0     1         *****          C11H18NO
# 22591  outl2731_3D_H_Ch.pdbqt   -4.0     2         *****          C11H18NO
# 22592  outl2731_3D_H_Ch.pdbqt   -3.9     3         *****          C11H18NO
# 22593  outl2731_3D_H_Ch.pdbqt   -3.8     4         *****          C11H18NO
# 22594  outl2731_3D_H_Ch.pdbqt   -3.8     5         *****          C11H18NO
# 22595  outl2731_3D_H_Ch.pdbqt   -3.8     6         *****          C11H18NO
# 22596  outl2731_3D_H_Ch.pdbqt   -3.8     7         *****          C11H18NO
# 22597  outl2731_3D_H_Ch.pdbqt   -3.7     8         *****          C11H18NO
# 22598  outl2731_3D_H_Ch.pdbqt   -3.6     9         *****          C11H18NO
# 22599  outl2661_3D_H_Ch.pdbqt   -4.7     1         *****          C11H12O3
# 22600  outl2661_3D_H_Ch.pdbqt   -4.6     2         *****          C11H12O3
# 22601  outl2661_3D_H_Ch.pdbqt   -4.6     3         *****          C11H12O3
# 22602  outl2661_3D_H_Ch.pdbqt   -4.6     4         *****          C11H12O3
# 22603  outl2661_3D_H_Ch.pdbqt   -4.6     5         *****          C11H12O3
# 22604  outl2661_3D_H_Ch.pdbqt   -4.4     6         *****          C11H12O3
# 22605  outl2661_3D_H_Ch.pdbqt   -4.3     7         *****          C11H12O3
# 22606  outl2661_3D_H_Ch.pdbqt   -4.1     8         *****          C11H12O3
# 22607  outl2661_3D_H_Ch.pdbqt   -4.1     9         *****          C11H12O3
#
#        molecular weight                                        smiles  \
# 0             170.22884  [C@H]1(C[N@@H]2CCCC[C@@H]2C1)C(=O)O\t*****\n
# 1             170.22884  [C@H]1(C[N@@H]2CCCC[C@@H]2C1)C(=O)O\t*****\n
# 2             170.22884  [C@H]1(C[N@@H]2CCCC[C@@H]2C1)C(=O)O\t*****\n
# 3             170.22884  [C@H]1(C[N@@H]2CCCC[C@@H]2C1)C(=O)O\t*****\n
# 4             170.22884  [C@H]1(C[N@@H]2CCCC[C@@H]2C1)C(=O)O\t*****\n
# 5             170.22884  [C@H]1(C[N@@H]2CCCC[C@@H]2C1)C(=O)O\t*****\n
# 6             170.22884  [C@H]1(C[N@@H]2CCCC[C@@H]2C1)C(=O)O\t*****\n
# 7             170.22884  [C@H]1(C[N@@H]2CCCC[C@@H]2C1)C(=O)O\t*****\n
# 8             170.22884  [C@H]1(C[N@@H]2CCCC[C@@H]2C1)C(=O)O\t*****\n
# 9             177.26608            C1(CCN(CC1)c1ccccc1)[NH3]\t*****\n
# 10            177.26608            C1(CCN(CC1)c1ccccc1)[NH3]\t*****\n
# 11            177.26608            C1(CCN(CC1)c1ccccc1)[NH3]\t*****\n
# 12            177.26608            C1(CCN(CC1)c1ccccc1)[NH3]\t*****\n
# 13            177.26608            C1(CCN(CC1)c1ccccc1)[NH3]\t*****\n
# 14            177.26608            C1(CCN(CC1)c1ccccc1)[NH3]\t*****\n
# 15            177.26608            C1(CCN(CC1)c1ccccc1)[NH3]\t*****\n
# 16            177.26608            C1(CCN(CC1)c1ccccc1)[NH3]\t*****\n
# 17            177.26608            C1(CCN(CC1)c1ccccc1)[NH3]\t*****\n
# 18            177.19984               c1(cc2CCC(=O)Nc2cc1)OC\t*****\n
# 19            177.19984               c1(cc2CCC(=O)Nc2cc1)OC\t*****\n
# 20            177.19984               c1(cc2CCC(=O)Nc2cc1)OC\t*****\n
# 21            177.19984               c1(cc2CCC(=O)Nc2cc1)OC\t*****\n
# 22            177.19984               c1(cc2CCC(=O)Nc2cc1)OC\t*****\n
# 23            177.19984               c1(cc2CCC(=O)Nc2cc1)OC\t*****\n
# 24            177.19984               c1(cc2CCC(=O)Nc2cc1)OC\t*****\n
# 25            177.19984               c1(cc2CCC(=O)Nc2cc1)OC\t*****\n
# 26            177.19984               c1(cc2CCC(=O)Nc2cc1)OC\t*****\n
# 27            194.21731   [C@@H]1(C2(CCC2)C[NH2]CC1)C(F)(F)F\t*****\n
# 28            194.21731   [C@@H]1(C2(CCC2)C[NH2]CC1)C(F)(F)F\t*****\n
# 29            194.21731   [C@@H]1(C2(CCC2)C[NH2]CC1)C(F)(F)F\t*****\n
# ...                 ...                                           ...
# 22578         217.21089  c1(cc(ncc1)[C@H]1C[NH2]CC1)C(F)(F)F\t*****\n
# 22579         217.21089  c1(cc(ncc1)[C@H]1C[NH2]CC1)C(F)(F)F\t*****\n
# 22580         217.21089  c1(cc(ncc1)[C@H]1C[NH2]CC1)C(F)(F)F\t*****\n
# 22581         162.20838               c1(oc2ccccc2c1)C[NH2]C\t*****\n
# 22582         162.20838               c1(oc2ccccc2c1)C[NH2]C\t*****\n
# 22583         162.20838               c1(oc2ccccc2c1)C[NH2]C\t*****\n
# 22584         162.20838               c1(oc2ccccc2c1)C[NH2]C\t*****\n
# 22585         162.20838               c1(oc2ccccc2c1)C[NH2]C\t*****\n
# 22586         162.20838               c1(oc2ccccc2c1)C[NH2]C\t*****\n
# 22587         162.20838               c1(oc2ccccc2c1)C[NH2]C\t*****\n
# 22588         162.20838               c1(oc2ccccc2c1)C[NH2]C\t*****\n
# 22589         162.20838               c1(oc2ccccc2c1)C[NH2]C\t*****\n
# 22590         180.26672      Cc1oc2CC(C)(C)C[C@H](c2c1)[NH3]\t*****\n
# 22591         180.26672      Cc1oc2CC(C)(C)C[C@H](c2c1)[NH3]\t*****\n
# 22592         180.26672      Cc1oc2CC(C)(C)C[C@H](c2c1)[NH3]\t*****\n
# 22593         180.26672      Cc1oc2CC(C)(C)C[C@H](c2c1)[NH3]\t*****\n
# 22594         180.26672      Cc1oc2CC(C)(C)C[C@H](c2c1)[NH3]\t*****\n
# 22595         180.26672      Cc1oc2CC(C)(C)C[C@H](c2c1)[NH3]\t*****\n
# 22596         180.26672      Cc1oc2CC(C)(C)C[C@H](c2c1)[NH3]\t*****\n
# 22597         180.26672      Cc1oc2CC(C)(C)C[C@H](c2c1)[NH3]\t*****\n
# 22598         180.26672      Cc1oc2CC(C)(C)C[C@H](c2c1)[NH3]\t*****\n
# 22599         192.21118         [C@]1(Cc2ccccc2CC1)(C(=O)O)O\t*****\n
# 22600         192.21118         [C@]1(Cc2ccccc2CC1)(C(=O)O)O\t*****\n
# 22601         192.21118         [C@]1(Cc2ccccc2CC1)(C(=O)O)O\t*****\n
# 22602         192.21118         [C@]1(Cc2ccccc2CC1)(C(=O)O)O\t*****\n
# 22603         192.21118         [C@]1(Cc2ccccc2CC1)(C(=O)O)O\t*****\n
# 22604         192.21118         [C@]1(Cc2ccccc2CC1)(C(=O)O)O\t*****\n
# 22605         192.21118         [C@]1(Cc2ccccc2CC1)(C(=O)O)O\t*****\n
# 22606         192.21118         [C@]1(Cc2ccccc2CC1)(C(=O)O)O\t*****\n
# 22607         192.21118         [C@]1(Cc2ccccc2CC1)(C(=O)O)O\t*****\n
#
#        het_atoms  rescoring
# 0              3  -1.133333
# 1              3  -1.133333
# 2              3  -1.133333
# 3              3  -1.133333
# 4              3  -1.133333
# 5              3  -1.133333
# 6              3  -1.133333
# 7              3  -1.133333
# 8              3  -1.133333
# 9              2  -1.850000
# 10             2  -1.850000
# 11             2  -1.850000
# 12             2  -1.850000
# 13             2  -1.850000
# 14             2  -1.850000
# 15             2  -1.850000
# 16             2  -1.850000
# 17             2  -1.850000
# 18             3  -1.300000
# 19             3  -1.300000
# 20             3  -1.300000
# 21             3  -1.300000
# 22             3  -1.300000
# 23             3  -1.300000
# 24             3  -1.300000
# 25             3  -1.300000
# 26             3  -1.300000
# 27             4  -0.900000
# 28             4  -0.900000
# 29             4  -0.900000
# ...          ...        ...
# 22578          5  -0.800000
# 22579          5  -0.800000
# 22580          5  -0.800000
# 22581          2  -1.750000
# 22582          2  -1.750000
# 22583          2  -1.750000
# 22584          2  -1.750000
# 22585          2  -1.750000
# 22586          2  -1.750000
# 22587          2  -1.750000
# 22588          2  -1.750000
# 22589          2  -1.750000
# 22590          2  -1.800000
# 22591          2  -1.800000
# 22592          2  -1.800000
# 22593          2  -1.800000
# 22594          2  -1.800000
# 22595          2  -1.800000
# 22596          2  -1.800000
# 22597          2  -1.800000
# 22598          2  -1.800000
# 22599          3  -1.366667
# 22600          3  -1.366667
# 22601          3  -1.366667
# 22602          3  -1.366667
# 22603          3  -1.366667
# 22604          3  -1.366667
# 22605          3  -1.366667
# 22606          3  -1.366667
# 22607          3  -1.366667
#
# [22608 rows x 9 columns]

# %% [markdown]
# ## Save the table to a csv file

# %%
table.to_csv ('no_sorted_scores.csv')
sort=table.sort_values ('score',ascending=False)
sort_rescoring=table.sort_values ('rescoring', ascending=False)
sort.to_csv ('sorted_scores.csv')
sort_rescoring.to_csv ('sorted_rescoring.csv')

# %% [markdown]
# ## Ploting options

# %%
plt.plot (list(table['molecular weight']),list(table['score']),'ro', marker='.')
plt.xlabel('molecular weight')
plt.ylabel ('score (Kcal/mol)')
# Out:
# Text(0,0.5,'score (Kcal/mol)')

# %%
plt.plot ((list(sort_rescoring.index)),list(sort_rescoring['rescoring']), 'ro',marker='.')
plt.xlabel('index')
plt.ylabel ('rescoring')
# Out:
# Text(0,0.5,'rescoring')

# %%
plt.plot ((list(sort_rescoring['score'])),list(sort_rescoring['rescoring']), 'ro',marker='.')
plt.xlabel('score')
plt.ylabel ('rescoring')
# Out:
# Text(0,0.5,'rescoring')

# %%
plt.plot ((list(sort.index)),list(sort['score']), 'ro',marker='.')
plt.xlabel('index')
plt.ylabel ('score (Kcal/mol)')
# Out:
# Text(0,0.5,'score (Kcal/mol)')

# %%
rescoring=[]
for i in range(len(table)):
    rescoring.append ((table['score'][i])/(table['het_atoms'][i]))

# %%
len (rescoring)
# Out:
# 276515

# %%
plt.plot (list(table['score']),rescoring,'ro', marker='.')
plt.xlabel('vina_score')
plt.ylabel ('rescore')
# Out:
# Text(0,0.5,'rescore')

# %%
rescoring=[]
for i in range(len(sort)):
    rescoring.append ((sort['score'][i])/(sort['het_atoms'][i]))

# %%
len (rescoring)
# Out:
# 276515

# %%
plt.plot (list(sort['score']),rescoring,'ro', marker='.')
plt.xlabel('vina_score')
plt.ylabel ('rescore')
# Out:
# Text(0,0.5,'rescore')

# %%
plt.plot (list(sort['molecular weight']),rescoring,'ro', marker='.')
plt.xlabel('mol weight')
plt.ylabel ('rescore')
# Out:
# Text(0,0.5,'rescore')

# %% [markdown]
# # Working with GOLD output (mol2) files

# %%
## NOT implemented yet

file ='/home/angel/Desktop/gold_soln_l1886_3D_H_Ch_m1_2.mol2'
with open(file,'rt') as file:
    for line in file:
            line = line.strip()
            if 'Gold.Score' in line:
                x=line.strip()
                print (x)

# %% [markdown]
# ## Extracting just the data from MODEL 1

# %%
os.chdir ('/Users/angel/Dropbox/Doctorado/Experimentos/zincinman_CD44_PYRX/Macromolecules/CD44_chimera/')
files=[]
names =[]
scores=[]
mass=[]
formula=[]
smiles=[]
model=[]
for file in glob.glob("*.pdbqt"):
    with open(file,'rt') as pdbqt_file:
        Nlines=pdbqt_file.readlines()[0:2]
        line = Nlines[1]
        line = line.strip()
        if "VINA RESULT" in line:
            neg = re.search(r'-\d.\d', line)
            neg_2= re.search (r'-\d\d.\d',line)
            if neg:
                files.append (pdbqt_file.name)
                scores.append (float(neg.group()))

            elif neg_2:
                files.append (pdbqt_file.name)
                scores.append (float(neg_2.group()))

            if not (neg or neg_2):
                files.append (pdbqt_file.name) 
                scores.append ('positive value, sorry I can´t keep it (yet)')
                    
    for mol in babel.readfile("pdbqt",file):
        if mol.data['MODEL']=='1':
            names.append (mol.title)
            mass.append (mol.molwt)
            formula.append (mol.formula)
            model.append (mol.data['MODEL'])
            smiles.append (mol)

d={ 'file':pd.Series(files),
    'score':pd.Series(scores),
    'model':pd.Series (model),
    'compound name':pd.Series(names),
    'molecular formula': pd.Series (formula),
    'molecular weight': pd.Series (mass),
    'smiles':pd.Series (smiles)}
table=pd.DataFrame (d)

# %%
table

# %%
os.chdir ('/Users/angel/Dropbox/Doctorado/Experimentos/zincinman_CD44_PYRX/Macromolecules/CD44_chimera/')
files=[]
names =[]
scores=[]
mass=[]
formula=[]
smiles=[]
model=[]
for file in glob.glob("*.pdbqt"):
    for mol in babel.readfile("pdbqt",file):
        if mol.data['MODEL']=='1':
            print (mol.title)

# %%
mol.
