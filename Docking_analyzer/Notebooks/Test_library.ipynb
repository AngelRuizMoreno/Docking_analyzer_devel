# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import sys
sys.path.append ('/home/angel/Documents/angel/projects/Docking_analyzer_devel/') #path for Angel in balmunt 
import os
import scores as sc

# %%
dock='/home/angel/Documents/fabiola/znd_CD36/vina/out_files/'

# %%
scores=sc.get_scores (docker='autodockvina',path=dock,save_csv=False, sort=True)
# Out:
# Raw score values
#                       file score
# 0       ZINC77265723.pdbqt  -8.1
# 1       ZINC77265723.pdbqt  -7.6
# 2       ZINC77265723.pdbqt  -7.6
# 3       ZINC77265723.pdbqt  -7.3
# 4       ZINC77265723.pdbqt  -7.3
# 5       ZINC77265723.pdbqt  -7.3
# 6       ZINC77265723.pdbqt  -7.3
# 7       ZINC77265723.pdbqt  -6.9
# 8       ZINC77265723.pdbqt  -6.8
# 9       ZINC03841760.pdbqt  -8.4
# 10      ZINC03841760.pdbqt  -7.8
# 11      ZINC03841760.pdbqt  -7.8
# 12      ZINC03841760.pdbqt  -7.6
# 13      ZINC03841760.pdbqt  -7.5
# 14      ZINC03841760.pdbqt  -7.1
# 15      ZINC03841760.pdbqt  -7.1
# 16      ZINC03841760.pdbqt  -7.0
# 17      ZINC03841760.pdbqt  -6.9
# 18      ZINC49170938.pdbqt  -9.6
# 19      ZINC49170938.pdbqt  -9.5
# 20      ZINC49170938.pdbqt  -9.4
# 21      ZINC49170938.pdbqt  -9.3
# 22      ZINC49170938.pdbqt  -9.0
# 23      ZINC49170938.pdbqt  -9.0
# 24      ZINC49170938.pdbqt  -8.8
# 25      ZINC49170938.pdbqt  -8.7
# 26      ZINC49170938.pdbqt  -8.7
# ...
